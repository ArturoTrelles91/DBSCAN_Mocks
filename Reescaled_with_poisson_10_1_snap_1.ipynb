# %%
a = []
while(1):
    a.append('1')

# %%
# Ejecuta esta celda para activar tu cuenta de Google Drive.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#from google.colab import drive
#drive.mount('/content/drive', force_remount=True)
#root_dir = "/content/drive/My Drive/"
#base_dir = root_dir + 'Playing_with_variables/'
#!ls "/content/drive/My Drive/DBSCAN_cone"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time

# %%
## Localiza el satelite de manera visual
Xp = pd.read_csv('/content/drive/My Drive/DBSCAN_cone/snapshotgra_001.ascii',sep='\s+')
Xp = Xp.drop(['m','eps'], axis = 1)

Xp = np.array(Xp)
print(np.shape(Xp))

# %%
"""plt.xlabel ('x (kpc)')
plt.ylabel ('z (kpc)')

plt.plot(Xp[0:11700,0]-cx,Xp[0:11700,2]-cz,'r.',markersize=1)
plt.show()"""

# %%
"""plt.xlabel ('x (kpc)')
plt.ylabel ('z (kpc)')

plt.xlim(-200,200)
plt.ylim(-200,200)

#plt.axvline(-1,c="b")
#plt.axhline(50,c="b")
horiz_line = 50
vert_line = -1

plt.hlines(y=horiz_line, xmin=-200, xmax=-1, color='blue', zorder=1)
plt.vlines(x=vert_line, ymin=-200, ymax=50, color='blue', zorder=2)

plt.plot(Xp[0:11700,0]-cx,Xp[0:11700,2]-cz,'r.',markersize=0.5)
plt.savefig('sate_real.png',dpi=300)
plt.show()"""

# %%
#plt.xlim(-45,-39)
#plt.ylim(-96,-85)
#plt.plot(Xp[0:11700,0],Xp[0:11700,2],'r.',markersize=1)
#plt.show()

#plt.ylim(-96,-85)
plt.plot(Xp[0:11700,0],Xp[0:11700,1],'b.',markersize=1)
plt.show()

# %%
f = 1000/0.7 # Mpc/h to kpc
  
#Calculadas con Rockstar para snap31
cx = 0.0
cy = 0.0
cz = 0.0

cx = cx*f
cy = cy*f
cz = cz*f

print(cx,cy,cz)
# Out:
# 0.0 0.0 0.0

# %%
#for the sattelite

#centro de masa del satelite en este snap
  
cxs =  125.
cys = 0.
czs =  25.

print(cxs,cys,czs)
# Out:
# 125.0 0.0 25.0

# %%
t0 = time.time()
XN = pd.read_csv('/content/drive/My Drive/DBSCAN_cone/snapshotgra_001.ascii',sep='\s+')
XN = XN.drop(['eps'], axis = 1)

XN['x'] = XN['x']-cx
XN['y'] = XN['y']-cy
XN['z'] = XN['z']-cz

# %%
rs= 50.
g = 1

NewX=XN['x']-cxs
NewY=XN['y']-cys

#if( (XN['z'] < 0) and (np.absolute(XN['z']) < np.absolute(g*czs))):
#XN = XN[ ((((XN['x']-cxs)/a1)**2.0 + ((XN['y']-cys)/b1)**2.0) < ((XN['z']/(2*czs))**2.0))]
XN = XN[ (np.absolute(XN['z']) < np.absolute(g*czs)) &((NewX)**2.0 + (NewY)**2.0 < (rs**2.0)*(XN['z']/(g*czs))**2.0)   ]
XN=np.array(XN)

# %%
print(np.shape(XN))

# %%
count= 0
count2=0
for i in range(np.shape(XN)[0]):
 if( XN[i,0] == 4.78 ):
  count = count + 1
 if( XN[i,0] < 4.78 ):
  count2 = count2 + 1 

print(count,count2,count+count2)
# Out:
# 5354 2210 7564

# %%
# -41.19428571428572 0.39571428571428574 -91.51857142857143
#plt.xlim(-50,50)
#plt.ylim(-100,100)
plt.figure()
plt.xlabel('x')
plt.ylabel('y')
#plt.plot(XN[:,1], XN[:,2],'r.')
plt.plot(XN[:,1][(XN[:,0] < 4.78 )], XN[:,2][(XN[:,0] < 4.78 )],'r.',markersize=2,label='H')
plt.plot(XN[:,1][(XN[:,0] == 4.78 )], XN[:,2][(XN[:,0] == 4.78 )],'b.',markersize=1,label='S')
plt.legend()
plt.show()


plt.figure()
plt.xlabel('x')
plt.ylabel('z')
#plt.plot(XN[:,1], XN[:,2],'r.')
plt.plot(XN[:,1][(XN[:,0] < 4.78 )], XN[:,3][(XN[:,0] < 4.78 )],'r.',markersize=2,label='H')
plt.plot(XN[:,1][(XN[:,0] == 4.78 )], XN[:,3][(XN[:,0] == 4.78 )],'b.',markersize=1,label='S')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8c7b2813b6e6> in <module>()
#       2 #plt.xlim(-50,50)
#       3 #plt.ylim(-100,100)
# ----> 4 plt.figure()
#       5 plt.xlabel('x')
#       6 plt.ylabel('y')
#
# NameError: name 'plt' is not defined

# %%
t0 = time.time()
XN = pd.read_csv('/content/drive/My Drive/DBSCAN_cone/snapshotgra_0031.ascii',sep='\s+')
XN = XN.drop(['eps'], axis = 1)

XN['x'] = XN['x']-cx
XN['y'] = XN['y']-cy
XN['z'] = XN['z']-cz

rs= 150.
g = 2

NewX=XN['x']-cxs
NewY=XN['y']-cys

XN = XN[ (XN['z'] < 0) & (np.absolute(XN['z']) < np.absolute(g*czs)) & ((NewX)**2.0 + (NewY)**2.0 < (rs**2.0)*(XN['z']/(g*czs))**2.0)   ]
#XN=np.array(XN)

#Tercer rango de pruebas
#XN = XN[ ((XN['x']) >= -130) & ((XN['x']) <= 25) & ((XN['y']) >= -15)& ((XN['y']) <= 15) & ((XN['z']) >=-180) & ((XN['z']) <= 0)]

# Definiendo una nueva columna utilizando la masa para saber si las particulas son del satelite o del halo
def sat(row): 
    if row["m"] == 4.78:
        sat = 1
    else:
        sat = 0
    return pd.Series(dict(sat=sat))

#anade la nueva columna
XN = XN.join(XN.apply(sat,axis="columns"))
XN = np.array(XN)
#indices de las particulas del satelite del archivo con cortes

# Las que no son del satelite
ind = np.where(XN[:,7] == 1)[0]
ind2 = np.where(XN[:,7] == 0)[0]
#print(np.shape(XN))

#print(XN)
#print(np.shape(XN))
print(time.time()-t0)

#print(ind2)
# Out:
# 18.07699489593506

# %%
print(np.shape(XN))
print(np.shape(XN[ind]))
print(np.shape(XN[ind2]))
# Out:
# (33985, 8)
# (151, 8)
# (33834, 8)

# %%
"""# estimando particulas a radius para estimar Np

Xc = pd.read_csv('/content/drive/My Drive/Playing_with_variables/snapshotgra_0031.ascii',sep='\s+')
Xc = Xc.drop(['eps'], axis = 1)

Xc['x'] = Xc['x']-cx
Xc['y'] = Xc['y']-cy
Xc['z'] = Xc['z']-cz

rc = ((Xc['x'])*(Xc['x']) + (Xc['y'])*(Xc['y'])+(Xc['z'])*(Xc['z']) )**0.5
#Tercer rango de pruebas
Xc = Xc[(rc < 3) & (Xc['m']!= 4.78 )]
print(np.shape(Xc))"""
# Out:
# "# estimando particulas a radius para estimar Np\n\nXc = pd.read_csv('/content/drive/My Drive/Playing_with_variables/snapshotgra_0031.ascii',sep='\\s+')\nXc = Xc.drop(['eps'], axis = 1)\n\nXc['x'] = Xc['x']-cx\nXc['y'] = Xc['y']-cy\nXc['z'] = Xc['z']-cz\n\nrc = ((Xc['x'])*(Xc['x']) + (Xc['y'])*(Xc['y'])+(Xc['z'])*(Xc['z']) )**0.5\n#Tercer rango de pruebas\nXc = Xc[(rc < 3) & (Xc['m']!= 4.78 )]\nprint(np.shape(Xc))"

# %%
## utilizar knn para tratar de estimar la densidad alrededor de cada particula
from sklearn.neighbors import NearestNeighbors
import time

t0 = time.time()
#Np = np.shape(XN)[0]

#original
#nbrs = NearestNeighbors(n_neighbors=int((np.shape(Xc)[0])/2), algorithm='auto',n_jobs=-1).fit(XN[:,1:4])

# ahora usa todo
nbrs = NearestNeighbors(n_neighbors=int((np.shape(XN)[0])), algorithm='auto',n_jobs=-1).fit(XN[:,1:4])

distances, indices = nbrs.kneighbors(XN[:,1:4])
print(time.time()-t0)

# %%
#Vamos a cambiar de r=3 a r=1
radius=1

Np = np.shape(XN)[0]
lend=[]
for i in range(Np):
    lend.append(len(np.where(distances[i] <= radius)[0]))    
#print(time.time()-t0)
#print(np.shape(lend))
#print(lend[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-493b24919107> in <module>()
#       2 radius=1
#       3
# ----> 4 Np = np.shape(XN)[0]
#       5 lend=[]
#       6 for i in range(Np):
#
# NameError: name 'np' is not defined

# %%
tmp = []
for i in range(Np):
    #lend=len(np.where(distances[i] <= 3.)[0])
    tmp.append((lend[i])/((4./3.)*(np.pi)*(radius**3)) )
    #print(lend[i])
    #print(len(np.where(distances[i] <= 3.)[0]))
#print(time.time()-t0)

# %%
rho_2=np.array(tmp)

#ind = XN[:,7]
#masses = XN[:,0]

vx = (XN[:,4])
vy = (XN[:,5])
vz = (XN[:,6])

#ff3 = np.absolute((min(vz) - max(vz))/( max(rho_2) - min(rho_2)))

New_Xt = np.vstack((vx,rho_2))

New_Xt=New_Xt.T

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

New_Xt = sc.fit_transform(New_Xt)

# %%
"""for j in range(1,41):
    m=j*10
    l=m+2
    
    nbrs = NearestNeighbors(n_neighbors=l, algorithm='auto').fit(New_Xt)
    distances, indices = nbrs.kneighbors(New_Xt)
    dist = [distances[i,m] for i in range(distances.shape[0])]

    plt.figure()
    plt.xlabel('bin (eps)')
    plt.ylabel('Neighbours in distances bin')
    #plt.axvline(0.22,c="r")
    plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
    plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
    plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
    plt.legend()
    #plt.savefig('histof4_pruebas.png',dpi=300)
    plt.show()
    print(l,m)"""

# %%
nbrs = NearestNeighbors(n_neighbors=402, algorithm='auto').fit(New_Xt)
distances, indices = nbrs.kneighbors(New_Xt)
dist = [distances[i,400] for i in range(distances.shape[0])]

plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.02,c="r")
plt.hist(np.array(dist),bins=np.arange(0,0.03,0.001),histtype='step',label='Total sample')
plt.hist(np.array(dist)[ind2],bins=np.arange(0,0.03,0.001),histtype='step',label='Only halo in total sample')
plt.hist(np.array(dist)[ind],bins=np.arange(0,0.03,0.001),histtype='step',label='Only sat in total sample')
plt.legend()
plt.savefig('/content/drive/My Drive/Playing_with_variables/Experimento_vx/histof4_pruebas_con_vx_0.02_400.png',dpi=300)
plt.show()
#print(l,m)

# %%
"""from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=302, algorithm='auto').fit(New_Xt)
distances, indices = nbrs.kneighbors(New_Xt)
dist = [distances[i,300] for i in range(distances.shape[0])]
          
plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.26,c="r")
plt.hist(np.array(dist),bins=np.arange(0,1,0.005))
plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005))
#plt.hist(np.array(dist0),bins=np.arange(0,1,0.005))
#plt.legend()
plt.savefig('histof.png',dpi=300)
plt.show()

plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.26,c="r")
plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step')
plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step')
plt.legend()
plt.savefig('histof2.png',dpi=300)
plt.show()

plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.26,c="r")
plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
plt.legend()
plt.savefig('histof3.png',dpi=300)
plt.show()


plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.26,c="k")
plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
#plt.hist(np.array(dist0),bins=np.arange(0,1,0.005),histtype='step',label='Only halo')
plt.legend()
plt.savefig('histof4_2.png',dpi=300)
plt.show()

plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
#plt.axvline(0.26,c="k")
plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
#plt.hist(np.array(dist0),bins=np.arange(0,1,0.005),histtype='step',label='Only halo')
plt.legend()
plt.savefig('histof4_2nl.png',dpi=300)
plt.show()"""

# %%
"""nbrs = NearestNeighbors(n_neighbors=122, algorithm='auto').fit(New_Xt)
distances, indices = nbrs.kneighbors(New_Xt)
dist = [distances[i,120] for i in range(distances.shape[0])]

plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.22,c="r")
plt.hist(np.array(dist),bins=np.arange(0,1.2,0.005),histtype='step',label='Total sample')
#plt.hist(np.array(dist)[ind2],bins=np.arange(0,1.2,0.005),histtype='step',label='Only halo in total sample')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1.2,0.005),histtype='step',label='Only sat in total sample')
plt.legend()
#plt.savefig('histof4_pruebas.png',dpi=300)
plt.show()"""

# %%
"""for j in range(1,41):
    m=j*10
    l=m+2
    
    nbrs = NearestNeighbors(n_neighbors=l, algorithm='auto').fit(New_Xt)
    distances, indices = nbrs.kneighbors(New_Xt)
    dist = [distances[i,m] for i in range(distances.shape[0])]

    plt.figure()
    plt.xlabel('bin (eps)')
    plt.ylabel('Neighbours in distances bin')
    #plt.axvline(0.22,c="r")
    plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
    plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
    plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
    plt.legend()
    #plt.savefig('histof4_pruebas.png',dpi=300)
    plt.show()
    print(l,m)"""

# %%
"""for j in range(41,61):
    m=j*10
    l=m+2
    
    nbrs = NearestNeighbors(n_neighbors=l, algorithm='auto').fit(New_Xt)
    distances, indices = nbrs.kneighbors(New_Xt)
    dist = [distances[i,m] for i in range(distances.shape[0])]

    plt.figure()
    plt.xlabel('bin (eps)')
    plt.ylabel('Neighbours in distances bin')
    #plt.axvline(0.22,c="r")
    plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
    plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
    plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
    plt.legend()
    #plt.savefig('histof4_pruebas.png',dpi=300)
    plt.show()
    print(l,m)"""

# %%
"""for j in range(61,101):
    m=j*10
    l=m+2
    
    nbrs = NearestNeighbors(n_neighbors=l, algorithm='auto').fit(New_Xt)
    distances, indices = nbrs.kneighbors(New_Xt)
    dist = [distances[i,m] for i in range(distances.shape[0])]

    plt.figure()
    plt.xlabel('bin (eps)')
    plt.ylabel('Neighbours in distances bin')
    #plt.axvline(0.22,c="r")
    plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
    plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
    plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
    plt.legend()
    #plt.savefig('histof4_pruebas.png',dpi=300)
    plt.show()
    print(l,m)"""

# %%
"""for j in range(31,151):
    m=j*10
    l=m+2
    
    nbrs = NearestNeighbors(n_neighbors=l, algorithm='auto').fit(New_Xt)
    distances, indices = nbrs.kneighbors(New_Xt)
    dist = [distances[i,m] for i in range(distances.shape[0])]

    plt.figure()
    plt.xlabel('bin (eps)')
    plt.ylabel('Neighbours in distances bin')
    #plt.axvline(0.22,c="r")
    plt.hist(np.array(dist),bins=np.arange(0,1.2,0.005),histtype='step',label='Total sample')
    plt.hist(np.array(dist)[ind2],bins=np.arange(0,1.2,0.005),histtype='step',label='Only halo in total sample')
    plt.hist(np.array(dist)[ind],bins=np.arange(0,1.2,0.005),histtype='step',label='Only sat in total sample')
    plt.legend()
    #plt.savefig('histof4_pruebas.png',dpi=300)
    plt.show()
    print(l,m)"""

# %%
"""nbrs = NearestNeighbors(n_neighbors=322, algorithm='auto').fit(New_Xt)
distances, indices = nbrs.kneighbors(New_Xt)
dist = [distances[i,320] for i in range(distances.shape[0])]

plt.figure()
plt.xlabel('bin (eps)')
plt.ylabel('Neighbours in distances bin')
plt.axvline(0.26,c="r")
plt.hist(np.array(dist),bins=np.arange(0,1,0.005),histtype='step',label='Total sample')
plt.hist(np.array(dist)[ind2],bins=np.arange(0,1,0.005),histtype='step',label='Only halo in total sample')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1,0.005),histtype='step',label='Only sat in total sample')
plt.legend()
#plt.savefig('histof4_pruebas.png',dpi=300)
plt.show()
print(l,m)"""

# %%
"""#if((dist > 0.1)&(dist < 0.26)):
indic = np.where ((np.array(dist) < 0.26) & (np.array(dist) > 0.1) & (XN[:,0]!=4.78))[0] 
indic2 = np.where ((np.array(dist) < 0.26) & (np.array(dist) > 0.1) & (XN[:,0]==4.78))[0] 

#plt.xlim(-50,0)
#plt.ylim(-50,50)
plt.figure()
plt.xlabel('x (kpc)')
plt.ylabel('z (kpc)')
plt.plot(XN[indic,1],XN[indic,3],'r.',markersize=1)
plt.plot(XN[indic2,1],XN[indic2,3],'b.',markersize=1)
plt.savefig('bothconf.png',dpi=300)


plt.figure()
plt.xlim(-50,50)
plt.ylim(-50,50)
plt.xlabel('x (kpc)')
plt.ylabel('z (kpc)')
plt.plot(XN[indic,1],XN[indic,3],'r.',markersize=1)
plt.plot(XN[indic2,1],XN[indic2,3],'b.',markersize=1)
plt.savefig('bothconf_lim.png',dpi=300)

plt.figure()
plt.xlabel('x (kpc)')
plt.ylabel('z (kpc)')
plt.plot(XN[indic,1],XN[indic,3],'r.',markersize=1)
plt.savefig('redconfxz.png',dpi=300)

plt.figure()
plt.xlabel('vx (km/s)')
plt.ylabel('vz (km/s)')
plt.plot(XN[indic,4],XN[indic,6],'r.',markersize=1)
plt.plot(XN[indic2,4],XN[indic2,6],'b.',markersize=1)
plt.savefig('bothconf.png',dpi=300)

plt.figure()
plt.xlabel('vx (km/s)')
plt.ylabel('vz (km/s)')
plt.plot(XN[indic,4],XN[indic,6],'r.',markersize=1)
plt.savefig('redconf.png',dpi=300)
#print(np.shape(XN[indic,1]))"""

# %%
"""from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=252, algorithm='auto').fit(New_Xt)

distances, indices = nbrs.kneighbors(New_Xt)
dist = [distances[i,10] for i in range(distances.shape[0])]
          
plt.figure()
plt.axvline(0.195,c="r")
plt.hist(np.array(dist0),bins=np.arange(0,1,0.01),label='')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1,.01),label='')
plt.legend()
plt.show()
plt.savefig('histosboth.png',dpi=300)

plt.figure()
plt.axvline(0.195,c="r")
plt.hist(np.array(dist0),bins=np.arange(0,1,0.01),label='halo only',histtype='step')
plt.hist(np.array(dist),bins=np.arange(0,1,.01),label='halo+sat',histtype='step')
#plt.hist(np.array(dist),bins=np.arange(0,1,.01),label='sat in halo+sat',histtype='step')
plt.hist(np.array(dist)[ind],bins=np.arange(0,1,.01),label='Sat only in halo+sat',histtype='step')
plt.legend()
plt.savefig('histodas.png',dpi=300)
plt.show()"""

"""plt.figure()
plt.axvline(0.195,c="r")
plt.hist(np.array(dist0),bins=np.arange(0,1,0.01),label='')
plt.hist(np.array(dist),bins=np.arange(0,1,.01),label='' )
plt.legend()
plt.savefig('histodas3.png',dpi=300)
plt.show()"""

# %%
"""# Aplicar features scaling to other velocity matrix
mean = np.array(sc.mean_)
var = np.array(sc.var_)

meaning = []
varis = []

for i in range(0,3):
    meaning.append(mean[i])
    varis.append(np.sqrt(var[i]))
print(meaning)

def scale_data(array,means=meaning,stds=(varis)):
    return (array-means)/stds

## Nuevos datos

Xv = pd.read_csv('../snapshotgra_0031.ascii',sep='\s+')
Xv = Xv.drop(['m','x','y','z','eps'], axis = 1)

Xv = np.array(Xv)
print(np.shape(Xv))
#Xv = Xv[11700:1011700,:]
"""
"""
print(np.shape(Xv))
print(Xv)

New_Xv = scale_data(Xv)"""

# %%
#!pip install tensorflow

# %%
from tensorflow.keras import backend
from tensorflow.keras import backend
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
import seaborn as sns
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D

# %%
"""#V=((XN[11700:1171700,4])**2.+(XN[11700:1171700,5])**2.0+(XN[11700:1171700,6])**2.0)**0.5

V=np.array(V)

rad_range = [0, 200]
n_bins = 50
hist, bins = np.histogram(V, bins=n_bins, range=rad_range,)
inds = np.digitize(V, bins=bins)

#print(inds)
radtp = (bins[:-1] + bins[1:])/2 
DBsize= 16

rmin3= (bins[:-1])**3
rmax3= (bins[1:])**3

rest=(bins[1:])**3 - (bins[:-1])**3

N_shell= (DBsize**3)*(hist)/((rest)) 
poisson =    np.sqrt(N_shell)    
plt.plot(radtp, poisson, 'r.') 
plt.xlabel('vel  [km/s]')
plt.ylabel('poisson ')
plt.savefig("filter_poisson.png")
print(hist)
"""

# %%
"""radtp=  np.vstack(radtp)
poisson = np.vstack(poisson)

dataset = pd.DataFrame({'radtp': radtp[:, 0], 'poisson': poisson[:, 0]})

G = [dataset['radtp'], dataset['poisson']]
G=np.array(G)
G=G.T

print(G[:,0],G[:,1])"""

# %%
#db = DBSCAN(eps=0.47, min_samples=40).fit(New_X)
#New_Xt2 = New_Xt[ind2]
db = DBSCAN(eps=0.02, min_samples=400).fit(New_Xt)
core_samples = np.zeros_like(db.labels_, dtype=bool)
core_samples[db.core_sample_indices_] = True
labels = db.labels_

unique_labels = np.unique(labels)
print(unique_labels)

# %%
full_fig, full_ax = plt.subplots()

#colors=plt.cm.Spectral(np.linspace(0,1, len(unique_labels)))
colors= sns.color_palette("Paired",380)

for (label, color) in zip(unique_labels, colors):
   
    class_member_mask = (labels == label)
        
    xy = XN[class_member_mask & core_samples]
    xy2 = XN[class_member_mask & ~core_samples]
    
    part_fig, part_ax = plt.subplots(subplot_kw=dict(xlim=(-200, 200), ylim=(-400 ,400)))
    
    indc = np.where(xy[:,7] == 0)[0]
    indf = np.where(xy2[:,7] == 0)[0]
    
    #print(inds)
    
    xx = xy[:,4]
    yy = xy[:,6]
    
    xx2 = xy2[:,4]
    yy2 = xy2[:,6]  
    
    #xxs = xy[~indc,4]
    #yys = xy[~indc,6]
    
    #xx2s = xy2[~indf,4]
    #yy2s = xy2[~indf,6] 
    
    #print(np.shape(yy2))        
    #if(label > -2):
        
    plt.title("DBSCAN on cluster with label {}".format(label))
    
     #full_fig, full_ax = plt.subplots(subplot_kw=dict(xlim=(-50, 50),ylim=(20, 65)))
        
    plt.xlabel("vx")
    plt.ylabel("vz")

    full_ax.set_xlabel('vx')  
    full_ax.set_ylabel('vz') 
        
    full_ax.plot(xx, yy, 'o', c=color,markersize=1)
    full_ax.plot(xx2, yy2,'o', c=color,markersize=1)

    part_ax.plot(xx, yy, 'o', c=color,markersize=0.1)
    part_ax.plot(xx2, yy2, 'o', c=color,markersize=0.1)   
    
    #full_ax.plot(xxs, yys, '*', c=color,markersize=1)
    #full_ax.plot(xx2s, yy2s,'*', c=color, markersize=1)

    #part_ax.plot(xxs, yys, '*', c='red',markersize=0.1)
    #part_ax.plot(xx2s, yy2s, '*', c='red',markersize=0.1)   
    
    full_fig.savefig("/content/drive/My Drive/Playing_with_variables/Experimento_vx/experimento_0.02_400/DBSCAN_vel_0.02_con_vx_400.png",dpi=300)
    #part_ax.set_title("Part %d" % i)
    part_fig.savefig("/content/drive/My Drive/Playing_with_variables/Experimento_vx/experimento_0.02_400/part_%d_con_vx_0.02_400.png" % label)
    #plt.show()

# %%
#indc = np.where( New_X[0 & core_samples] )[0]

# %%
full_fig, full_ax = plt.subplots()

#colors=plt.cm.Spectral(np.linspace(0,1, len(unique_labels)))
colors= sns.color_palette("Paired",310)

for (label, color) in zip(unique_labels, colors):
   
    class_member_mask = (labels == label)
    
    xy = XN[class_member_mask & core_samples]
    xy2 = XN[class_member_mask & ~core_samples]

    part_fig, part_ax = plt.subplots(subplot_kw=dict(xlim=(-130, 20), ylim=(-180 ,0)))
    
    
    count=0
    for k in range(0,np.shape(xy[:,1])[0]):  
        if( (xy[k,7] == 0) ):            
            count=count+1
    print(count, ' particulas del halo en los puntos core con etiqueta',label, 'de un total de',np.shape(xy[:,1])) 
         
    count=0 
    for k in range(0,np.shape(xy2[:,1])[0]):     
        if( (xy2[k,7] == 0) ):           
            count=count+1
    print(count, 'particulas del halo en los puntos frontera con etiqueta',label,'de un total de',np.shape(xy2[:,1]))  
    
    
    indc = np.where(xy[:,7] == 0)[0]
    indf = np.where(xy2[:,7] == 0)[0]
    
    xx = xy[:,1]
    yy = xy[:,3]
    #xic = xy[indc,7]
     
    xx2 = xy2[:,1]
    yy2 = xy2[:,3]
    #xib = xy2[indf,7]
    
    #xxs = xy[~indc,1]
    #yys = xy[~indc,3]
    #xics = xy[~indc,7]
    
    #xx2s = xy2[~indf,1]
    #yy2s = xy2[~indf,3] 
    #xibs = xy2[~indf,7]
    
    plt.title("DBSCAN on cluster with label {}".format(label))
    
     #full_fig, full_ax = plt.subplots(subplot_kw=dict(xlim=(-50, 50),ylim=(20, 65)))
        
    plt.xlabel("x")
    plt.ylabel("z")
        
    #plt.xlim()    
    #plt.ylim()
    
    full_ax.set_xlabel('x')  
    full_ax.set_ylabel('z') 
        
    full_ax.plot(xx, yy, 'o', c=color,markersize=0.5)
    full_ax.plot(xx2,yy2,'o', c=color,markersize=0.5)

    part_ax.plot(xx, yy, 'o', c=color,markersize=0.5)
    part_ax.plot(xx2, yy2, 'o', c=color,markersize=0.5)   
        
    #full_ax.plot(xxs, yys, '*', c='red',markersize=0.5)
    #ull_ax.plot(xx2s, yy2s,'*', c='red', markersize=0.5)

    #part_ax.plot(xxs, yys, '*', c='red',markersize=0.5)
    #part_ax.plot(xx2s, yy2s, '*', c='red',markersize=0.5)     
    
    full_fig.savefig("/content/drive/My Drive/Playing_with_variables/Experimento_vx/experimento_0.02_400/DBSCAN_pos_con_vx_0.02_400.png",dpi=300)
    #part_ax.set_title("Part %d" % i)
    part_fig.savefig("/content/drive/My Drive/Playing_with_variables/Experimento_vx/experimento_0.02_400/part_pos_%d_con_vx_0.02_400.png" % label)
     #plt.show()
